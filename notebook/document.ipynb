# %% [markdown]
#  ### Data Ingestion

# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is main content ",
    metadata={
        "source":"e.txt",
        "pages":1,
        "author":"Ad"
    }
    
)
doc
# Out:
# Document(metadata={'source': 'e.txt', 'pages': 1, 'author': 'Ad'}, page_content='this is main content ')

# %%
## Create a simple txt file 
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
###TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
doc=loader.load()
print(doc)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
###DirectoryLoader
from langchain_community.document_loaders import DirectoryLoader,TextLoader

##load all the files from the directory

dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt",
    loader_cls=TextLoader,
    loader_kwargs={'encoding':'utf-8'},
    show_progress=False
)

docs=dir_loader.load()

# %%
###Load PDF
from langchain_community.document_loaders import DirectoryLoader,TextLoader,PyPDFLoader,PyMuPDFLoader

##load all the files from the directory

dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
 
    show_progress=False
)

pdf_docs=dir_loader.load()
pdf_docs
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.25', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-06-03T18:33:12+00:00', 'source': '../data/pdf/AdityaResume.pdf', 'file_path': '../data/pdf/AdityaResume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-06-03T18:33:12+00:00', 'trapped': '', 'modDate': 'D:20260603183312Z', 'creationDate': 'D:20260603183312Z', 'page': 0}, page_content='Aditya Prasannan\n+91-8955833540 | adityaprasannan.1si21cs004@gmail.com | LinkedIn | Github | Leetcode\nEducation\n• Siddaganga Institute Of Technology\n2021-2025\nBachelor of Engineering in Computer Science\nCGPA: 8.98\n• Cambridge Court High School\n2016-2020\nJaipur,Rajasthan\nExperience\n• Oracle\nJune 2025-Present\nAssociate Software Engineer\nBengaluru\n– Designed and implemented an AI-driven solution to automatically generate standardized Business Requirement\nDocuments (BRDs) from Zoom AI meeting summaries, eliminating manual documentation effort and reducing\nrequirement gaps and rework.\n– Built an Oracle Integration Cloud assessment utility that scans exported integration artifacts and generates\nhealth/compliance reports across areas like complexity, synchronous/asynchronous flow patterns, fault handling,\nversion drift, unused integrations, and configuration risks.\n– Building an automated agent workflow to compare new and past SRs, summarize key details, and send contextual\nSlack notifications containing both new and similar SRs for faster issue resolution.\n• Target\nFebruary 2025-June 2025\nApprentice Tech-Software Developer\nBengaluru\n– Implemented conditional access validation logic for TAP integrated overwatch applications\n– Implemented UI test cases for the Overwatch application to ensure feature reliability, covering key user flows,\nedge cases.\n– Gaining hands-on experience in full stack development using SpringBoot,Kotlin,Reactjs and PostgreSQL\nPersonal Projects\n• Inventory Management System\nA robust Inventory Management System with complete stock control, sales tracking, and real-time reporting of warehouse operations.\n– Built an Inventory Management System (IMS) with full CRUD functionality to manage warehouse stock, including\nadding new products and updating existing inventory.\n– Implemented stock operations allowing users to add products, sell items by removing them from inventory, and\nmaintain real-time stock levels.\n– Generated detailed transaction reports tracking all inbound and outbound stock movements for better visibility\nand warehouse auditing.\n– Technology used: Reactjs,SpringBoot,Kotlin,PostgreSQL\n– Github Link\n• JobPortal\nAn innovative job portal designed to connect professionals with tailored opportunities.\n– Filter job listings by title, location, posting time, and more.\n– Implemented user authentication and registration using email, password.\n– Allow registered users to post, edit, and manage their job listings.\n– Implemented pagination and crafted an awesome UI for an outstanding user experience.\n– Technology used: TailwindCSS, React.js, Node.js, Express.js, MongoDB\n– Github Link\nTechnical Skills\nLanguages:C/C++,Python,JavaScript, HTML/CSS\nDeveloper Tools: Git, Docker,Visual Studio\nFrameworks: React,Redux,Node.js,Express.js,FastAPI,LangChain\nDatabases:MongoDB,MySQL,Oracle Database 23ai\nCloud Technologies:Amazon Web Services(AWS)\nCoursework: Object-Oriented Programming, Computer Networks, Operating System, Database Management\nSystem, Data Structures and Algorithms\nCertifications and Achievements\nSuccessfully completed the course on DSA Live Training Program. Certificate\nSolved 400+ problems on various coding platforms')]

# %%
type(pdf_docs[0])
# type(docs)
# Out:
# langchain_core.documents.base.Document
